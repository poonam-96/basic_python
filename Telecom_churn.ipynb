# %% [markdown]
# # Data Preprocessing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Ingest Data

# %%
tel_df = pd.read_csv('telecom_churn.csv')

# %%
tel_df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
type(tel_df)
# Out:
# pandas.core.frame.DataFrame

# %%
tel_df.head(20)
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 0     KS             128        415                 No             Yes
# 1     OH             107        415                 No             Yes
# 2     NJ             137        415                 No              No
# 3     OH              84        408                Yes              No
# 4     OK              75        415                Yes              No
# 5     AL             118        510                Yes              No
# 6     MA             121        510                 No             Yes
# 7     MO             147        415                Yes              No
# 8     LA             117        408                 No              No
# 9     WV             141        415                Yes             Yes
# 10    IN              65        415                 No              No
# 11    RI              74        415                 No              No
# ...

# %%
tel_df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
type(tel_df.shape)
# Out:
# tuple

# %%
tel_df.shape
# Out:
# (3333, 20)

# %%
tel_df.size
# Out:
# 66660

# %%
l = [7,8,9]
l[0]
# Out:
# 7

# %%
tel_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
type(tel_df['State'])
# Out:
# pandas.core.series.Series

# %%
tel_df.head()['Account length']
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account length, dtype: int64

# %%
tel_df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
a = {'a':[1,3.4,2]}

# %%
df = pd.DataFrame(a)

# %%
df
# Out:
#      a
# 0  1.0
# 1  3.4
# 2  2.0

# %%
df.dtypes
# Out:
# a    float64
# dtype: object

# %%
tel_df.head(1)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False

# %%
tel_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
sub_copy = tel_df[['State', 'Account length', 'Area code', 'International plan',
       'Voice mail plan', 'Number vmail messages']]

# %%
sub_copy.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages
# 0                     25
# 1                     26
# 2                      0
# 3                      0
# 4                      0

# %%
sub_copy = tel_df['State']

# %%
sub_copy
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
# Get a section of rows by row number
tel_smalldf = tel_df[0:101]

# %%
tel_smalldf
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      KS             128        415                 No             Yes
# 1      OH             107        415                 No             Yes
# 2      NJ             137        415                 No              No
# 3      OH              84        408                Yes              No
# 4      OK              75        415                Yes              No
# ..    ...             ...        ...                ...             ...
# 96     MT              73        415                 No              No
# 97     AZ              99        415                 No              No
# 98     MS             120        408                 No              No
# 99     ID              77        415                 No              No
# 100    IA              98        510                 No             Yes
#
#      Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
l = [1,2,3,4]

# %%
l[1:3]
# Out:
# [2, 3]

# %%
sub_copy = tel_df[['State', 'Account length', 'Area code', 'International plan',
       'Voice mail plan', 'Number vmail messages']]
sub_copy = sub_copy[0:101:2]

# %%
sub_copy.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 2    NJ             137        415                 No              No
# 4    OK              75        415                Yes              No
# 6    MA             121        510                 No             Yes
# 8    LA             117        408                 No              No
#
#    Number vmail messages
# 0                     25
# 2                      0
# 4                      0
# 6                     24
# 8                      0

# %%
tel_df['State'].unique()
# Out:
# array(['ks', 'oh', 'nj', 'ok', 'al', 'ma', 'mo', 'la', 'wv', 'in', 'ri',
#        'ia', 'mt', 'ny', 'id', 'vt', 'va', 'tx', 'fl', 'co', 'az', 'sc',
#        'ne', 'wy', 'hi', 'il', 'nh', 'ga', 'ak', 'md', 'ar', 'wi', 'or',
#        'mi', 'de', 'ut', 'ca', 'mn', 'sd', 'nc', 'wa', 'nm', 'nv', 'dc',
#        'ky', 'me', 'ms', 'tn', 'pa', 'ct', 'nd'], dtype=object)

# %%
len(tel_df['State'].unique())
# Out:
# 51

# %%
tel_df['State'] = tel_df['State'].str.lower()

# %%
tel_df.head(1)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    ks             128        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
#
#    Customer service calls  Churn
# 0                       1  False

# %%
tel_df["multiplied_messages"] = tel_df['Number vmail messages']*2

# %%
tel_df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    ks             128        415                 No             Yes
# 1    oh             107        415                 No             Yes
# 2    nj             137        415                 No              No
# 3    oh              84        408                Yes              No
# 4    ok              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %%
l = [1,2,3]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3

# %%
tel_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn', 'multiplied_messages'],
#       dtype='object')

# %%
small_df = tel_df.loc[:100,['State','Total night calls','Total eve calls']]
small_df['total'] = small_df['Total night calls'] + small_df['Total eve calls']
small_df['total_mul'] = small_df['total']*0.2
small_df['total_int'] = small_df['total_mul'].astype('int')
small_df['total_round'] = round(small_df['total_mul']).astype('int')

# %%
a = 1.56
round(a,1)
# Out:
# 1.6

# %%
type(a)
# Out:
# float

# %%
int(a)
# Out:
# 1

# %%
small_df
# Out:
#     State  Total night calls  Total eve calls  total  total_mul  total_int  \
# 0      ks                 91               99    190       38.0         38
# 1      oh                103              103    206       41.2         41
# 2      nj                104              110    214       42.8         42
# 3      oh                 89               88    177       35.4         35
# 4      ok                121              122    243       48.6         48
# ..    ...                ...              ...    ...        ...        ...
# 96     mt                 72               72    144       28.8         28
# 97     az                113               76    189       37.8         37
# 98     ms                 96              104    200       40.0         40
# 99     id                109              126    235       47.0         47
# 100    ia                 92               83    175       35.0         35
#
#      total_round
# 0             38
# 1             41
# ...
