# %% [markdown]
# # Data Preprocessing and Data Visualization Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("datasets_2619_4359_pokemon.csv")

# %%
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data.shape
# Out:
# (800, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
data['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
data['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
# Correlation map
f,ax = plt.subplots(figsize=(9,9))
sns.heatmap(data.corr(),annot=True,ax=ax,fmt='.1f',linewidths=.5)
plt.show()

# %%
data.boxplot(column='Attack',by='Legendary')

# %%
data_new = data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
melted = pd.melt(frame=data_new,id_vars='Name',value_vars=['Attack','Defense'])

# %%
melted
# Out:
#             Name variable  value
# 0      Bulbasaur   Attack     49
# 1        Ivysaur   Attack     62
# 2       Venusaur   Attack     82
# 3  Mega Venusaur   Attack    100
# 4     Charmander   Attack     52
# 5      Bulbasaur  Defense     49
# 6        Ivysaur  Defense     63
# 7       Venusaur  Defense     83
# 8  Mega Venusaur  Defense    123
# 9     Charmander  Defense     43

# %%
melted.pivot(index='Name',columns='variable',values='value')
# Out:
# variable       Attack  Defense
# Name
# Bulbasaur          49       49
# Charmander         52       43
# Ivysaur            62       63
# Mega Venusaur     100      123
# Venusaur           82       83

# %%
data_new = data.head()
data_new
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data_new.pivot(index='Name',columns='Type 1',values=['Attack','Defense'])
# Out:
#               Attack        Defense
# Type 1          Fire  Grass    Fire  Grass
# Name
# Bulbasaur        NaN   49.0     NaN   49.0
# Charmander      52.0    NaN    43.0    NaN
# Ivysaur          NaN   62.0     NaN   63.0
# Mega Venusaur    NaN  100.0     NaN  123.0
# Venusaur         NaN   82.0     NaN   83.0

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
data["Type 2"].isnull().sum()
# Out:
# 386

# %%
data["Type 2"].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ghost        14
# Rock         14
# Water        14
# Ice          14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data1 = data.copy()

# %%
data1.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
data1['Type 2'].fillna('empty',inplace=True)

# %%
data1.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire   empty  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
data1['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
data1['Type 2'].unique()
# Out:
# array(['Poison', 'empty', 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
data2 = data.set_index(['Type 1','Type 2'])

# %%
data2
# Out:
#                   #            Name  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1  Type 2
# Grass   Poison    1       Bulbasaur  45      49       49       65       65
#         Poison    2         Ivysaur  60      62       63       80       80
#         Poison    3        Venusaur  80      82       83      100      100
#         Poison    4   Mega Venusaur  80     100      123      122      120
# Fire    NaN       5      Charmander  39      52       43       60       50
# ...             ...             ...  ..     ...      ...      ...      ...
# Rock    Fairy   796         Diancie  50     100      150      100      150
#         Fairy   797    Mega Diancie  50     160      110      160      110
# Psychic Ghost   798  Hoopa Confined  80     110       60      150      130
#         Dark    799   Hoopa Unbound  80     160       60      170      130
# Fire    Water   800       Volcanion  80     110      120      130       90
#
#                 Speed  Generation  Legendary
# ...

# %%
data1
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       98       65
# 1      2         Ivysaur    Grass  Poison  60      62      126       80
# 2      3        Venusaur    Grass  Poison  80      82      166      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      246      122
# 4      5      Charmander     Fire   empty  39      52       86       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      300      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      220      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110      120      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160      120      170
# 799  800       Volcanion     Fire   Water  80     110      240      130
#
#      Sp. Def  Speed  Generation  Legendary  Defense_2
# ...

# %%
data1.groupby("Type 1")[["HP","Attack"]].agg(['mean','sum'])
# Out:
#                  HP            Attack
#                mean   sum        mean   sum
# Type 1
# Bug       56.884058  3925   70.971014  4897
# Dark      66.806452  2071   88.387097  2740
# Dragon    83.312500  2666  112.125000  3588
# Electric  59.795455  2631   69.090909  3040
# Fairy     74.117647  1260   61.529412  1046
# Fighting  69.851852  1886   96.777778  2613
# Fire      69.903846  3635   84.769231  4408
# Flying    70.750000   283   78.750000   315
# Ghost     64.437500  2062   73.781250  2361
# Grass     67.271429  4709   73.214286  5125
# Ground    73.781250  2361   95.750000  3064
# Ice       72.000000  1728   72.750000  1746
# Normal    77.275510  7573   73.469388  7200
# Poison    67.250000  1883   74.678571  2091
# Psychic   70.631579  4026   71.456140  4073
# Rock      65.363636  2876   92.863636  4086
# Steel     65.222222  1761   92.703704  2503
# Water     72.062500  8071   74.151786  8305

# %%
percentage_people_below_poverty_level = pd.read_csv(
    'datasets_2647_4395_PercentagePeopleBelowPovertyLevel.csv',encoding="windows-1252")
kill = pd.read_csv('datasets_2647_4395_PoliceKillingsUS.csv',encoding="windows-1252")
percent_over_25_completed_highschool = pd.read_csv(
    'datasets_2647_4395_PercentOver25CompletedHighSchool.csv',encoding="windows-1252")

# %%
percentage_people_below_poverty_level.head()
# Out:
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
percentage_people_below_poverty_level.dtypes
# Out:
# Geographic Area    object
# City               object
# poverty_rate       object
# dtype: object

# %%
percentage_people_below_poverty_level['poverty_rate'].replace(['-'],0.0,inplace=True)

# %%
percentage_people_below_poverty_level['poverty_rate'] = percentage_people_below_poverty_level['poverty_rate'].astype(float)

# %%
percentage_people_below_poverty_level.dtypes
# Out:
# Geographic Area     object
# City                object
# poverty_rate       float64
# dtype: object

# %%
area_list = list(percentage_people_below_poverty_level['Geographic Area'].unique())
area_poverty_ratio = []
for i in area_list:
    x = percentage_people_below_poverty_level[percentage_people_below_poverty_level['Geographic Area']==i]
    area_poverty_rate = sum(x.poverty_rate)/len(x)
    area_poverty_ratio.append(area_poverty_rate)

# %%
data = pd.DataFrame({'area_list':area_list,'area_poverty_ratio':area_poverty_ratio})
new_index = (data['area_poverty_ratio'].sort_values(ascending=False)).index.values
sorted_data = data.reindex(new_index).reset_index(drop=True)
plt.figure(figsize=(10,5))
sns.barplot(x=sorted_data['area_list'],y=sorted_data['area_poverty_ratio'])
plt.xticks(rotation=80)
plt.xlabel('States')
plt.ylabel('Povert rate')
plt.title('Poverty Rate Given States')
plt.show()

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.name.unique()
# Out:
# array(['Tim Elliot', 'Lewis Lee Lembke', 'John Paul Quintero', ...,
#        'Dennis W. Robinson', 'Isaiah Tucker', 'Dwayne Jeune'],
#       dtype=object)
